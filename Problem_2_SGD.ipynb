# %% [markdown]
# # **Imports:**

# %%
import torchvision as tv
from torch.utils.data import DataLoader
import torch.utils.data
import random
import numpy as np
import torchvision.transforms as transforms
from numpy import linalg as la
import torch.nn as nn

# %% [markdown]
# # **Neural Network Class:**

# %%
class Network(nn.Module):
    def __init__(self, input_size,num_classes,dropout):
        super(Network,self).__init__()
        self.fc1 = nn.Linear(input_size, num_classes)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self,x):
        out = self.dropout(x)
        out = self.fc1(out)
        out = self.relu(out)
        out = self.softmax(out)
        return out

# %% [markdown]
# # **Training and Validation Process:**

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

batch_size = 32
num_epochs = 200
learning_rate = 0.01
num_classes = 10
num_features = 784
train50Len = 30000
val50Len = 5000


device = "cuda" if torch.cuda.is_available() else "cpu"
transform = transforms.Compose(
[transforms.ToTensor(),
]
)

train = tv.datasets.MNIST('../data',transform = transform, download=True,train=True)
val = tv.datasets.MNIST('../data',transform = transform, download=True,train=False)



My_list = [*range(0, 60000, 1)]
My_list1 = [*range(0, 10000, 1)]

strain = torch.utils.data.Subset(train, random.sample(My_list, train50Len))
sval = torch.utils.data.Subset(val, random.sample(My_list1, val50Len))



netlayers = Network(num_features, num_classes,dropout=0.25)
if torch.cuda.is_available():
    netlayers.to(device)

loss_function = nn.NLLLoss()
optimizer = torch.optim.SGD(netlayers.parameters(), lr=learning_rate)



train_loader = torch.utils.data.DataLoader(strain, batch_size=batch_size,
                                            shuffle=True)
val_loader = torch.utils.data.DataLoader(sval, batch_size=batch_size,
                                            shuffle=True)

loss = []
valloss = []
trainingacc = []
validationacc = []
AllBatchTrainLoss = []
AllBatchValLoss = []
batchtrainingacc = []
batchvalidationacc = []

for epoch in range(num_epochs):
    print("Epoch: ",epoch+1 )
    train_accuracy = 0
    test_accuracy = 0
    epochtrainloss = []
    epochtestloss = []
    netlayers.train()
    for i ,(images,labels) in enumerate(train_loader):
            images = images.view(-1,28*28).to(device) 
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = netlayers(images)
#           print(outputs.shape," ",labels.shape)
            Tloss = loss_function(outputs, labels)
            epochtrainloss.append(Tloss.cpu().item())
            AllBatchTrainLoss.append(Tloss.cpu().item())
            _, predicted = torch.max(outputs,1)     
            train_accuracy += np.count_nonzero(predicted.cpu().data.numpy() == labels.cpu().data.numpy())
            batchtrainingacc.append((np.count_nonzero(predicted.cpu().data.numpy() == labels.cpu().data.numpy())) * 100)
            Tloss.backward()
            optimizer.step()   
    loss.append(np.mean(epochtrainloss))
    trainingacc.append((train_accuracy/train50Len) *100)
    print("Train Accuracy:",(train_accuracy/train50Len) *100)
    netlayers.eval()
    for i ,(images,labels) in enumerate(val_loader):
            images = images.view(-1,28*28).to(device)
            labels = labels.to(device)
            outputs = netlayers(images)
            validloss = loss_function(outputs, labels)
            epochtestloss.append(validloss.cpu().item())
            AllBatchValLoss.append(validloss.cpu().item())
            _, predicted = torch.max(outputs,1)     
            test_accuracy += np.count_nonzero(predicted.cpu().data.numpy() == labels.cpu().data.numpy())
            batchvalidationacc.append((np.count_nonzero(predicted.cpu().data.numpy() == labels.cpu().data.numpy())) * 100)
    valloss.append(np.mean(epochtestloss))
    validationacc.append((test_accuracy/val50Len) *100)
    print("Test Accuracy:",(test_accuracy/val50Len) *100)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Epoch:  1
# Train Accuracy: 76.75666666666666
# Test Accuracy: 87.12
# Epoch:  2
# Train Accuracy: 85.14
# Test Accuracy: 88.84
# Epoch:  3
# Train Accuracy: 86.45333333333333
# Test Accuracy: 89.3
# Epoch:  4
# Train Accuracy: 87.22666666666666
# Test Accuracy: 90.03999999999999
# Epoch:  5
# Train Accuracy: 87.46000000000001
# Test Accuracy: 90.25999999999999
# Epoch:  6
# Train Accuracy: 87.9
# Test Accuracy: 90.48
# Epoch:  7
# Train Accuracy: 87.98333333333333
# Test Accuracy: 90.8
# Epoch:  8
# Train Accuracy: 88.49000000000001
# Test Accuracy: 90.96
# Epoch:  9
# Train Accuracy: 88.47
# Test Accuracy: 91.10000000000001
# Epoch:  10
# Train Accuracy: 88.74333333333333
# Test Accuracy: 91.12
# Epoch:  11
# Train Accuracy: 88.74666666666667
# Test Accuracy: 91.28
# Epoch:  12
# Train Accuracy: 89.25
# Test Accuracy: 91.46
# Epoch:  13
# Train Accuracy: 89.19666666666667
# Test Accuracy: 91.42
# Epoch:  14
# Train Accuracy: 89.33333333333333
# Test Accuracy: 91.42
# Epoch:  15
# Train Accuracy: 89.47666666666667
# Test Accuracy: 91.36
# Epoch:  16
# Train Accuracy: 89.45666666666666
# Test Accuracy: 91.52
# Epoch:  17
# Train Accuracy: 89.51666666666667
# Test Accuracy: 91.62
# Epoch:  18
# Train Accuracy: 89.62333333333333
# Test Accuracy: 91.64
# Epoch:  19
# Train Accuracy: 89.57666666666667
# Test Accuracy: 91.53999999999999
# Epoch:  20
# Train Accuracy: 89.64333333333333
# Test Accuracy: 91.62
# Epoch:  21
# Train Accuracy: 89.76333333333332
# Test Accuracy: 91.66
# Epoch:  22
# Train Accuracy: 89.70333333333333
# Test Accuracy: 91.7
# Epoch:  23
# Train Accuracy: 89.79666666666667
# Test Accuracy: 91.72
# Epoch:  24
# Train Accuracy: 89.68666666666667
# Test Accuracy: 91.78
# Epoch:  25
# Train Accuracy: 89.9
# Test Accuracy: 91.84
# Epoch:  26
# Train Accuracy: 89.9
# Test Accuracy: 91.75999999999999
# Epoch:  27
# Train Accuracy: 90.15333333333334
# Test Accuracy: 91.92
# Epoch:  28
# Train Accuracy: 89.97666666666667
# Test Accuracy: 91.75999999999999
# Epoch:  29
# Train Accuracy: 90.01666666666667
# Test Accuracy: 91.92
# Epoch:  30
# Train Accuracy: 90.06666666666666
# Test Accuracy: 91.94
# Epoch:  31
# Train Accuracy: 90.08333333333334
# Test Accuracy: 91.94
# Epoch:  32
# Train Accuracy: 90.22333333333333
# Test Accuracy: 91.92
# Epoch:  33
# Train Accuracy: 90.13
# Test Accuracy: 92.06
# Epoch:  34
# Train Accuracy: 90.18
# Test Accuracy: 91.9
# Epoch:  35
# Train Accuracy: 90.09
# Test Accuracy: 92.06
# Epoch:  36
# Train Accuracy: 90.18
# Test Accuracy: 92.04
# Epoch:  37
# Train Accuracy: 90.08333333333334
# Test Accuracy: 92.10000000000001
# Epoch:  38
# Train Accuracy: 90.26666666666667
# Test Accuracy: 91.96
# Epoch:  39
# Train Accuracy: 90.19
# Test Accuracy: 92.04
# Epoch:  40
# Train Accuracy: 90.25
# Test Accuracy: 92.04
# Epoch:  41
# Train Accuracy: 90.11
# Test Accuracy: 92.14
# Epoch:  42
# Train Accuracy: 90.21000000000001
# Test Accuracy: 92.12
# Epoch:  43
# Train Accuracy: 90.27
# Test Accuracy: 92.12
# Epoch:  44
# Train Accuracy: 90.36999999999999
# Test Accuracy: 92.16
# Epoch:  45
# Train Accuracy: 90.42
# Test Accuracy: 92.14
# Epoch:  46
# Train Accuracy: 90.38666666666667
# Test Accuracy: 92.2
# Epoch:  47
# Train Accuracy: 90.55
# Test Accuracy: 92.24
# Epoch:  48
# Train Accuracy: 90.58
# Test Accuracy: 92.10000000000001
# Epoch:  49
# Train Accuracy: 90.45333333333333
# Test Accuracy: 92.24
# Epoch:  50
# Train Accuracy: 90.34333333333333
# Test Accuracy: 92.17999999999999
# Epoch:  51
# Train Accuracy: 90.57333333333332
# Test Accuracy: 92.17999999999999
# Epoch:  52
# Train Accuracy: 90.50666666666667
# Test Accuracy: 92.17999999999999
# Epoch:  53
# Train Accuracy: 90.50666666666667
# Test Accuracy: 92.25999999999999
# Epoch:  54
# Train Accuracy: 90.63
# Test Accuracy: 92.28
# Epoch:  55
# Train Accuracy: 90.64666666666666
# Test Accuracy: 92.14
# Epoch:  56
# Train Accuracy: 90.48666666666666
# Test Accuracy: 92.34
# Epoch:  57
# Train Accuracy: 90.53999999999999
# Test Accuracy: 92.17999999999999
# Epoch:  58
# Train Accuracy: 90.65333333333334
# Test Accuracy: 92.4
# Epoch:  59
# Train Accuracy: 90.64999999999999
# Test Accuracy: 92.4
# Epoch:  60
# Train Accuracy: 90.59333333333333
# Test Accuracy: 92.24
# Epoch:  61
# Train Accuracy: 90.67
# Test Accuracy: 92.54
# Epoch:  62
# Train Accuracy: 90.48333333333333
# Test Accuracy: 92.38
# Epoch:  63
# Train Accuracy: 90.63333333333333
# Test Accuracy: 92.42
# Epoch:  64
# Train Accuracy: 90.53999999999999
# Test Accuracy: 92.36
# Epoch:  65
# Train Accuracy: 90.65666666666667
# Test Accuracy: 92.28
# Epoch:  66
# Train Accuracy: 90.8
# Test Accuracy: 92.24
# Epoch:  67
# Train Accuracy: 90.67
# Test Accuracy: 92.46
# Epoch:  68
# Train Accuracy: 90.64333333333333
# Test Accuracy: 92.30000000000001
# Epoch:  69
# Train Accuracy: 90.72333333333333
# Test Accuracy: 92.30000000000001
# Epoch:  70
# Train Accuracy: 90.87333333333333
# Test Accuracy: 92.34
# Epoch:  71
# Train Accuracy: 90.60333333333334
# Test Accuracy: 92.4
# Epoch:  72
# Train Accuracy: 90.75666666666666
# Test Accuracy: 92.47999999999999
# Epoch:  73
# Train Accuracy: 90.61666666666667
# Test Accuracy: 92.22
# Epoch:  74
# Train Accuracy: 90.55333333333333
# Test Accuracy: 92.38
# Epoch:  75
# Train Accuracy: 90.80333333333334
# Test Accuracy: 92.36
# Epoch:  76
# Train Accuracy: 90.70666666666666
# Test Accuracy: 92.42
# Epoch:  77
# Train Accuracy: 90.67666666666668
# Test Accuracy: 92.36
# Epoch:  78
# Train Accuracy: 90.70666666666666
# Test Accuracy: 92.28
# Epoch:  79
# Train Accuracy: 90.57666666666667
# Test Accuracy: 92.47999999999999
# Epoch:  80
# Train Accuracy: 90.59
# Test Accuracy: 92.42
# Epoch:  81
# Train Accuracy: 90.73666666666666
# Test Accuracy: 92.32000000000001
# Epoch:  82
# Train Accuracy: 90.75666666666666
# Test Accuracy: 92.42
# Epoch:  83
# Train Accuracy: 90.71333333333334
# Test Accuracy: 92.38
# Epoch:  84
# Train Accuracy: 90.85
# Test Accuracy: 92.28
# Epoch:  85
# Train Accuracy: 90.59333333333333
# Test Accuracy: 92.10000000000001
# Epoch:  86
# Train Accuracy: 90.80666666666667
# Test Accuracy: 92.46
# Epoch:  87
# Train Accuracy: 90.67666666666668
# Test Accuracy: 92.36
# Epoch:  88
# Train Accuracy: 90.81666666666666
# Test Accuracy: 92.54
# Epoch:  89
# Train Accuracy: 90.96333333333332
# Test Accuracy: 92.47999999999999
# Epoch:  90
# Train Accuracy: 90.81333333333333
# Test Accuracy: 92.47999999999999
# Epoch:  91
# Train Accuracy: 90.88333333333334
# Test Accuracy: 92.36
# Epoch:  92
# Train Accuracy: 90.94333333333333
# Test Accuracy: 92.42
# Epoch:  93
# Train Accuracy: 90.84666666666666
# Test Accuracy: 92.32000000000001
# Epoch:  94
# Train Accuracy: 90.66666666666666
# Test Accuracy: 92.44
# Epoch:  95
# Train Accuracy: 90.87333333333333
# Test Accuracy: 92.47999999999999
# Epoch:  96
# Train Accuracy: 90.84666666666666
# Test Accuracy: 92.47999999999999
# Epoch:  97
# Train Accuracy: 90.97
# Test Accuracy: 92.36
# Epoch:  98
# Train Accuracy: 90.89666666666668
# Test Accuracy: 92.60000000000001
# Epoch:  99
# Train Accuracy: 91.02333333333334
# Test Accuracy: 92.46
# Epoch:  100
# Train Accuracy: 90.85333333333332
# Test Accuracy: 92.38
# Epoch:  101
# Train Accuracy: 90.88666666666667
# Test Accuracy: 92.42
# Epoch:  102
# Train Accuracy: 90.91333333333334
# Test Accuracy: 92.4
# Epoch:  103
# Train Accuracy: 90.92333333333333
# Test Accuracy: 92.5
# Epoch:  104
# Train Accuracy: 90.81666666666666
# Test Accuracy: 92.4
# Epoch:  105
# Train Accuracy: 90.98333333333333
# Test Accuracy: 92.44
# Epoch:  106
# Train Accuracy: 90.73333333333333
# Test Accuracy: 92.36
# Epoch:  107
# Train Accuracy: 90.78
# Test Accuracy: 92.52
# Epoch:  108
# Train Accuracy: 90.98666666666666
# Test Accuracy: 92.46
# Epoch:  109
# Train Accuracy: 90.74333333333333
# Test Accuracy: 92.56
# Epoch:  110
# Train Accuracy: 91.12333333333333
# Test Accuracy: 92.38
# Epoch:  111
# Train Accuracy: 90.94666666666666
# Test Accuracy: 92.56
# Epoch:  112
# Train Accuracy: 90.94333333333333
# Test Accuracy: 92.44
# Epoch:  113
# Train Accuracy: 91.13666666666667
# Test Accuracy: 92.60000000000001
# Epoch:  114
# Train Accuracy: 90.99333333333334
# Test Accuracy: 92.58
# Epoch:  115
# Train Accuracy: 91.07666666666667
# Test Accuracy: 92.62
# Epoch:  116
# Train Accuracy: 90.85666666666667
# Test Accuracy: 92.42
# Epoch:  117
# Train Accuracy: 90.94666666666666
# Test Accuracy: 92.52
# Epoch:  118
# Train Accuracy: 91.12333333333333
# Test Accuracy: 92.47999999999999
# Epoch:  119
# Train Accuracy: 90.96666666666667
# Test Accuracy: 92.5
# Epoch:  120
# Train Accuracy: 91.08666666666667
# Test Accuracy: 92.56
# Epoch:  121
# Train Accuracy: 91.02333333333334
# Test Accuracy: 92.58
# Epoch:  122
# Train Accuracy: 90.78666666666668
# Test Accuracy: 92.5
# Epoch:  123
# Train Accuracy: 90.86999999999999
# Test Accuracy: 92.56
# Epoch:  124
# Train Accuracy: 90.85
# Test Accuracy: 92.47999999999999
# Epoch:  125
# Train Accuracy: 91.02
# Test Accuracy: 92.54
# Epoch:  126
# Train Accuracy: 91.20666666666666
# Test Accuracy: 92.5
# Epoch:  127
# Train Accuracy: 91.02666666666667
# Test Accuracy: 92.47999999999999
# Epoch:  128
# Train Accuracy: 91.08666666666667
# Test Accuracy: 92.46
# Epoch:  129
# Train Accuracy: 91.05666666666666
# Test Accuracy: 92.56
# Epoch:  130
# Train Accuracy: 90.83
# Test Accuracy: 92.62
# Epoch:  131
# Train Accuracy: 91.22
# Test Accuracy: 92.64
# Epoch:  132
# Train Accuracy: 91.01666666666667
# Test Accuracy: 92.52
# Epoch:  133
# Train Accuracy: 91.17666666666666
# Test Accuracy: 92.47999999999999
# Epoch:  134
# Train Accuracy: 90.89333333333333
# Test Accuracy: 92.64
# Epoch:  135
# Train Accuracy: 91.10000000000001
# Test Accuracy: 92.62
# Epoch:  136
# Train Accuracy: 91.00666666666667
# Test Accuracy: 92.46
# Epoch:  137
# Train Accuracy: 90.91666666666667
# Test Accuracy: 92.56
# Epoch:  138
# Train Accuracy: 91.03999999999999
# Test Accuracy: 92.42
# Epoch:  139
# Train Accuracy: 90.84666666666666
# Test Accuracy: 92.52
# Epoch:  140
# Train Accuracy: 91.07666666666667
# Test Accuracy: 92.62
# Epoch:  141
# Train Accuracy: 91.09
# Test Accuracy: 92.64
# Epoch:  142
# Train Accuracy: 91.03
# Test Accuracy: 92.66
# Epoch:  143
# Train Accuracy: 91.05333333333333
# Test Accuracy: 92.64
# Epoch:  144
# Train Accuracy: 91.08000000000001
# Test Accuracy: 92.66
# Epoch:  145
# Train Accuracy: 90.94666666666666
# Test Accuracy: 92.62
# Epoch:  146
# Train Accuracy: 91.00666666666667
# Test Accuracy: 92.60000000000001
# Epoch:  147
# Train Accuracy: 90.98666666666666
# Test Accuracy: 92.56
# Epoch:  148
# Train Accuracy: 91.0
# Test Accuracy: 92.74
# Epoch:  149
# Train Accuracy: 91.08000000000001
# Test Accuracy: 92.67999999999999
# Epoch:  150
# Train Accuracy: 91.07333333333332
# Test Accuracy: 92.62
# Epoch:  151
# Train Accuracy: 91.03
# Test Accuracy: 92.62
# Epoch:  152
# Train Accuracy: 90.91666666666667
# Test Accuracy: 92.74
# Epoch:  153
# Train Accuracy: 91.14333333333333
# Test Accuracy: 92.64
# Epoch:  154
# Train Accuracy: 91.25666666666666
# Test Accuracy: 92.67999999999999
# Epoch:  155
# Train Accuracy: 91.05
# Test Accuracy: 92.74
# Epoch:  156
# Train Accuracy: 91.03666666666666
# Test Accuracy: 92.78
# Epoch:  157
# Train Accuracy: 90.92333333333333
# Test Accuracy: 92.72
# Epoch:  158
# Train Accuracy: 91.16333333333333
# Test Accuracy: 92.64
# Epoch:  159
# Train Accuracy: 91.14
# Test Accuracy: 92.80000000000001
# Epoch:  160
# Train Accuracy: 91.24666666666667
# Test Accuracy: 92.62
# Epoch:  161
# Train Accuracy: 91.25
# Test Accuracy: 92.60000000000001
# Epoch:  162
# Train Accuracy: 91.12666666666667
# Test Accuracy: 92.74
# Epoch:  163
# Train Accuracy: 91.06
# Test Accuracy: 92.67999999999999
# Epoch:  164
# Train Accuracy: 91.05333333333333
# Test Accuracy: 92.66
# Epoch:  165
# Train Accuracy: 91.18333333333334
# Test Accuracy: 92.75999999999999
# Epoch:  166
# Train Accuracy: 91.13666666666667
# Test Accuracy: 92.74
# Epoch:  167
# Train Accuracy: 90.95333333333333
# Test Accuracy: 92.78
# Epoch:  168
# Train Accuracy: 91.08333333333334
# Test Accuracy: 92.64
# Epoch:  169
# Train Accuracy: 91.11666666666667
# Test Accuracy: 92.64
# Epoch:  170
# Train Accuracy: 91.10666666666667
# Test Accuracy: 92.7
# Epoch:  171
# Train Accuracy: 91.33333333333333
# Test Accuracy: 92.7
# Epoch:  172
# Train Accuracy: 91.18666666666667
# Test Accuracy: 92.66
# Epoch:  173
# Train Accuracy: 90.96333333333332
# Test Accuracy: 92.7
# Epoch:  174
# Train Accuracy: 91.08666666666667
# Test Accuracy: 92.67999999999999
# Epoch:  175
# Train Accuracy: 91.11
# Test Accuracy: 92.74
# Epoch:  176
# Train Accuracy: 91.12666666666667
# Test Accuracy: 92.7
# Epoch:  177
# Train Accuracy: 91.44666666666666
# Test Accuracy: 92.80000000000001
# Epoch:  178
# Train Accuracy: 91.23
# Test Accuracy: 92.78
# Epoch:  179
# Train Accuracy: 91.15333333333334
# Test Accuracy: 92.74
# Epoch:  180
# Train Accuracy: 91.26333333333334
# Test Accuracy: 92.7
# Epoch:  181
# Train Accuracy: 91.14
# Test Accuracy: 92.67999999999999
# Epoch:  182
# Train Accuracy: 91.2
# Test Accuracy: 92.72
# Epoch:  183
# Train Accuracy: 91.04333333333334
# Test Accuracy: 92.74
# Epoch:  184
# Train Accuracy: 90.99000000000001
# Test Accuracy: 92.78
# Epoch:  185
# Train Accuracy: 91.14999999999999
# Test Accuracy: 92.74
# Epoch:  186
# Train Accuracy: 91.18
# Test Accuracy: 92.74
# Epoch:  187
# Train Accuracy: 91.20333333333333
# Test Accuracy: 92.7
# Epoch:  188
# Train Accuracy: 91.34666666666666
# Test Accuracy: 92.72
# Epoch:  189
# Train Accuracy: 91.24666666666667
# Test Accuracy: 92.75999999999999
# Epoch:  190
# Train Accuracy: 91.24333333333333
# Test Accuracy: 92.80000000000001
# Epoch:  191
# Train Accuracy: 91.14666666666666
# Test Accuracy: 92.75999999999999
# Epoch:  192
# Train Accuracy: 91.12666666666667
# Test Accuracy: 92.82000000000001
# Epoch:  193
# Train Accuracy: 91.31
# Test Accuracy: 92.82000000000001
# Epoch:  194
# Train Accuracy: 91.23333333333333
# Test Accuracy: 92.67999999999999
# Epoch:  195
# Train Accuracy: 91.32333333333334
# Test Accuracy: 92.74
# Epoch:  196
# Train Accuracy: 91.2
# Test Accuracy: 92.78
# Epoch:  197
# Train Accuracy: 91.25333333333333
# Test Accuracy: 92.82000000000001
# Epoch:  198
# Train Accuracy: 91.13666666666667
# Test Accuracy: 92.74
# Epoch:  199
# Train Accuracy: 91.17666666666666
# Test Accuracy: 92.78
# Epoch:  200
# Train Accuracy: 91.09333333333333
# Test Accuracy: 92.75999999999999

# %% [markdown]
# # **Training/Validation Epochwise Loss:**

# %%
import matplotlib.pyplot as plt
plt.title("Training/Validation Loss:")
plt.plot(loss,color = 'r', label="Training Loss")
plt.plot(valloss,label="validation Loss")
leg = plt.legend(loc='upper right')
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# # **Training/Validation Epochwise Accuracy:**

# %%
plt.title("Training/validation Accuracy")
plt.plot(trainingacc,color = 'r',label="Training Acc")
plt.plot(validationacc,label="Validation Acc")
leg = plt.legend(loc='lower right')
plt.xlabel("Epochs")
plt.ylabel("Accuracy%")
print(max(trainingacc))
print(max(validationacc))
# Out:
# 91.44666666666666
# 92.82000000000001

# %% [markdown]
# # **Training/Validation Epochwise Error:**

# %%
plt.title("Training/validation Error")
plt.plot(100-np.array(trainingacc),color = 'r',label="Training Error")
plt.plot(100-np.array(validationacc),label="Validation Error")
leg = plt.legend(loc='upper right')
plt.xlabel("Epochs")
plt.ylabel("Training Error%")
print("Final Train accuracy: ",max(trainingacc))
print("Final Test accuracy: ", max(validationacc))
# Out:
# Final Train accuracy:  91.44666666666666
# Final Test accuracy:  92.82000000000001

# %% [markdown]
# # **Training/Validation Batchwise Error:**

# %%
plt.title("Training/validation Batchwise Error")
plt.plot(100-(np.array(batchtrainingacc)/batch_size), color = 'r',label="Training Error")
plt.plot(100-(np.array(batchvalidationacc)/batch_size), color = 'b',label="Validation Error")
leg = plt.legend(loc='upper right')
plt.xlabel("Epochs")
plt.ylabel("Error%")
# Out:
# Text(0, 0.5, 'Error%')

# %% [markdown]
# # **Training/Validation Batchwise Accuracy:**

# %%
plt.title("Training/validation Batchwise Acc")
plt.plot((np.array(batchtrainingacc)/batch_size), color = 'r',label="Training Acc")
plt.plot((np.array(batchvalidationacc)/batch_size), color = 'b',label="Validation Acc")
leg = plt.legend(loc='lower right')
plt.xlabel("Epochs")
plt.ylabel("Acc%")
# Out:
# Text(0, 0.5, 'Acc%')

# %% [markdown]
# # **Training/Validation Batchwise Loss:**

# %%
import matplotlib.pyplot as plt
plt.title("Batchwise Loss:")
plt.plot(AllBatchTrainLoss,color = 'r', label="Training Loss")
plt.plot(AllBatchValLoss,color = 'b', label="Testing Loss")
leg = plt.legend(loc='upper right')
plt.xlabel("Batches")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
